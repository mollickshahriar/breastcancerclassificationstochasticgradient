# %% [markdown]
# # Importing All necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
import pandas as pd
data = pd.read_csv("data.csv")
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")
print(data.head(10))
print("\n\n\n\n")
print(train_data.head(10))
print("\n\n\n\n")
print(test_data.head(10))
print("\n\n\n\n")
# Out:
#    a         b         c         d         e         f         g         h  \
# 0  2 -0.860107 -0.111111 -1.000000 -1.000000 -1.000000 -0.777778 -1.000000
# 1  2 -0.859671 -0.111111 -0.333333 -0.333333 -0.111111  0.333333  1.000000
# 2  2 -0.857807 -0.555556 -1.000000 -1.000000 -1.000000 -0.777778 -0.777778
# 3  2 -0.857680  0.111111  0.555556  0.555556 -1.000000 -0.555556 -0.333333
# 4  2 -0.857569 -0.333333 -1.000000 -1.000000 -0.555556 -0.777778 -1.000000
# 5  4 -0.857554  0.555556  1.000000  1.000000  0.555556  0.333333  1.000000
# 6  2 -0.857408 -1.000000 -1.000000 -1.000000 -1.000000 -0.777778  1.000000
# 7  2 -0.857339 -0.777778 -1.000000 -0.777778 -1.000000 -0.777778 -1.000000
# 8  2 -0.855171 -0.777778 -1.000000 -1.000000 -1.000000 -0.777778 -1.000000
# 9  2 -0.855171 -0.333333 -0.777778 -1.000000 -1.000000 -0.777778 -1.000000
#
#           i         j         k
# 0 -0.555556 -1.000000 -1.000000
# 1 -0.555556 -0.777778 -1.000000
# 2 -0.555556 -1.000000 -1.000000
# ...

# %% [markdown]
# # shape

# %%
train_data.shape
# Out:
# (400, 11)

# %% [markdown]
# # Null Values

# %%
train_data.isnull().values.any()
# Out:
# False

# %%
train_data.isnull().sum()
# Out:
# a    0
# b    0
# c    0
# d    0
# e    0
# f    0
# g    0
# h    0
# i    0
# j    0
# k    0
# dtype: int64

# %%
sns.heatmap(train_data.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Information

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       400 non-null    int64
#  1   b       400 non-null    float64
#  2   c       400 non-null    float64
#  3   d       400 non-null    float64
#  4   e       400 non-null    float64
#  5   f       400 non-null    float64
#  6   g       400 non-null    float64
#  7   h       400 non-null    float64
#  8   i       400 non-null    float64
#  9   j       400 non-null    float64
#  10  k       400 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 34.5 KB

# %% [markdown]
# # Summary statistics

# %%
train_data.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean     2.860000   -0.861136   -0.190000   -0.460000   -0.438889   -0.559444
# std      0.991392    0.042824    0.687198    0.684170    0.668405    0.646868
# min      2.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      2.000000   -0.885539   -0.777778   -1.000000   -1.000000   -1.000000
# 50%      2.000000   -0.841916   -0.333333   -0.777778   -0.777778   -1.000000
# 75%      4.000000   -0.830751    0.333333   -0.111111   -0.055556   -0.333333
# max      4.000000   -0.817131    1.000000    1.000000    1.000000    1.000000
#
#                 g           h           i           j           k
# count  400.000000  400.000000  400.000000  400.000000  400.000000
# mean    -0.428333   -0.296667   -0.390000   -0.493333   -0.814444
# std      0.546362    0.853885    0.487727    0.706298    0.444321
# ...

# %% [markdown]
# # Correlation

# %%
train_data.corr()
# Out:
#           a         b         c         d         e         f         g  \
# a  1.000000 -0.071457  0.748928  0.778485  0.796275  0.673948  0.648873
# b -0.071457  1.000000 -0.034082 -0.011961 -0.041784 -0.100906  0.012526
# c  0.748928 -0.034082  1.000000  0.673127  0.685902  0.472905  0.504117
# d  0.778485 -0.011961  0.673127  1.000000  0.898727  0.658030  0.733559
# e  0.796275 -0.041784  0.685902  0.898727  1.000000  0.639105  0.697058
# f  0.673948 -0.100906  0.472905  0.658030  0.639105  1.000000  0.551555
# g  0.648873  0.012526  0.504117  0.733559  0.697058  0.551555  1.000000
# h  0.813999 -0.124667  0.615770  0.669593  0.702025  0.650066  0.548413
# i  0.679264 -0.042862  0.561951  0.679073  0.666498  0.592446  0.557067
# j  0.691737 -0.028966  0.551239  0.697128  0.706324  0.591078  0.606454
# k  0.435903 -0.010481  0.367878  0.491163  0.457852  0.431841  0.474542
#
#           h         i         j         k
# a  0.813999  0.679264  0.691737  0.435903
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(train_data.corr(),annot=True,fmt='.0%',cmap='Blues')
plt.show()

# %%
plt.figure(figsize=(16,10))
train_data.drop('a',axis=1).corrwith(train_data['a']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("Correlation with Target Variable")
# Out:
# Text(0.5, 1.0, 'Correlation with Target Variable')

# %% [markdown]
# # Data Visualization with target variable

# %%
train_data.plot.scatter(x="b", y="a")
# Out:
# <AxesSubplot:xlabel='b', ylabel='a'>

# %%
train_data.plot.scatter(x="c", y="a")
# Out:
# <AxesSubplot:xlabel='c', ylabel='a'>

# %%
train_data.plot.scatter(x="d", y="a")
# Out:
# <AxesSubplot:xlabel='d', ylabel='a'>

# %%
train_data.plot.scatter(x="e", y="a")
# Out:
# <AxesSubplot:xlabel='e', ylabel='a'>

# %%
train_data.plot.scatter(x="f", y="a")
# Out:
# <AxesSubplot:xlabel='f', ylabel='a'>

# %%
train_data.plot.scatter(x="g", y="a")
# Out:
# <AxesSubplot:xlabel='g', ylabel='a'>

# %%
train_data.plot.scatter(x="h", y="a")
# Out:
# <AxesSubplot:xlabel='h', ylabel='a'>

# %%
train_data.plot.scatter(x="i", y="a")
# Out:
# <AxesSubplot:xlabel='i', ylabel='a'>

# %%
train_data.plot.scatter(x="j", y="a")
# Out:
# <AxesSubplot:xlabel='j', ylabel='a'>

# %%
train_data.plot.scatter(x="k", y="a")
# Out:
# <AxesSubplot:xlabel='k', ylabel='a'>

# %% [markdown]
# # Outliers

# %%
train_data.plot(kind='box',subplots=True,layout=(4,5),color='green',figsize=(13,13))
plt.tight_layout()

# %% [markdown]
# # Skewness

# %%
import itertools
cols=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
length=len(cols)
cs=["b","r","g","c","m","k","lime"]
fig=plt.figure(figsize=(13,25))

for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(3,4,j+1)
    ax=sns.distplot(train_data[i],color=k,rug=True)
    ax.set_facecolor("w")
    plt.axvline(train_data[i].mean(),linestyle="dashed",label="mean",color="k")
    plt.legend(loc="best")
    plt.title(i,color="navy")
    plt.xlabel("")

# %%
train_data.skew()
# Out:
# a    0.283851
# b   -1.380878
# c    0.442365
# d    1.054513
# e    0.933498
# f    1.385029
# g    1.390352
# h    0.635257
# i    0.892244
# j    1.108011
# k    2.820767
# dtype: float64

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# ### Z_Score

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(train_data))
threshold=3
df=train_data[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (378, 11)

# %% [markdown]
# ### IQR

# %%
q1=train_data.quantile(0.25)
q3=train_data.quantile(0.75)
IQR=q3-q1
print(IQR)
df_new1=train_data[~((train_data<(q1-1.5*IQR))|(train_data>(q3+1.5*IQR))).any(axis=1)]
print(df_new1.shape)
# Out:
# a    2.000000
# b    0.054788
# c    1.111111
# d    0.888889
# e    0.944445
# f    0.666667
# g    0.666667
# h    1.777778
# i    0.666667
# j    0.888889
# k    0.000000
# dtype: float64
# (280, 11)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.utils import shuffle

# %% [markdown]
# # FEATURE SELECTION

# %%
def remove_correlated_features(X):
    corr_threshold = 0.9
    corr = X.corr()
    drop_columns = np.full(corr.shape[0], False, dtype=bool)
    for i in range(corr.shape[0]):
        for j in range(i + 1, corr.shape[0]):
            if corr.iloc[i, j] >= corr_threshold:
                drop_columns[j] = True
    columns_dropped = X.columns[drop_columns]
    X.drop(columns_dropped, axis=1, inplace=True)
    return columns_dropped


def remove_less_significant_features(X, Y):
    sl = 0.05
    regression_ols = None
    columns_dropped = np.array([])
    for itr in range(0, len(X.columns)):
        regression_ols = sm.OLS(Y, X).fit()
        max_col = regression_ols.pvalues.idxmax()
        max_val = regression_ols.pvalues.max()
        if max_val > sl:
            X.drop(max_col, axis='columns', inplace=True)
            columns_dropped = np.append(columns_dropped, [max_col])
        else:
            break
    regression_ols.summary()
    return columns_dropped

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.svm import SVC
#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV,cross_val_score
def compute_cost(W, X, Y):
    # calculate hinge loss
    N = X.shape[0]
    distances = 1 - Y * (np.dot(X, W))
    distances[distances < 0] = 0  # equivalent to max(0, distance)
    hinge_loss = regularization_strength * (np.sum(distances) / N)

    # calculate cost
    cost = 1 / 2 * np.dot(W, W) + hinge_loss
    return cost

# %%
def calculate_cost_gradient(W, X_batch, Y_batch):
    # if only one example is passed (eg. in case of SGD)
    if type(Y_batch) == np.float64:
        Y_batch = np.array([Y_batch])
        X_batch = np.array([X_batch])  # gives multidimensional array

    distance = 1 - (Y_batch * np.dot(X_batch, W))
    dw = np.zeros(len(W))

    for ind, d in enumerate(distance):
        if max(0, d) == 0:
            di = W
        else:
            di = W - (regularization_strength * Y_batch[ind] * X_batch[ind])
        dw += di

    dw = dw/len(Y_batch)  # average
    return dw


def sgd(features, outputs):
    max_epochs = 5000
    weights = np.zeros(features.shape[1])
    nth = 0
    prev_cost = float("inf")
    cost_threshold = 0.01  # in percent
   # stochastic gradient descent 
    for epoch in range(1, max_epochs):
        # shuffle to prevent repeating update cycles
        X, Y = shuffle(features, outputs)
        for ind, x in enumerate(X):
            ascent = calculate_cost_gradient(weights, x, Y[ind])
            weights = weights - (learning_rate * ascent)
            
        # convergence check on 2^nth epoch
        if epoch == 2 ** nth or epoch == max_epochs - 1:
            cost = compute_cost(weights, features, outputs)
            print("Epoch is: {} and Cost is: {}".format(epoch, cost))
            # stoppage criterion
            if abs(prev_cost - cost) < cost_threshold * prev_cost:
                return weights
            prev_cost = cost
            nth += 1
    return weights

# %%
df.head(10)
# Out:
#    a         b         c         d         e         f         g         h  \
# 0  2 -0.860107 -0.111111 -1.000000 -1.000000 -1.000000 -0.777778 -1.000000
# 1  2 -0.859671 -0.111111 -0.333333 -0.333333 -0.111111  0.333333  1.000000
# 2  2 -0.857807 -0.555556 -1.000000 -1.000000 -1.000000 -0.777778 -0.777778
# 3  2 -0.857680  0.111111  0.555556  0.555556 -1.000000 -0.555556 -0.333333
# 4  2 -0.857569 -0.333333 -1.000000 -1.000000 -0.555556 -0.777778 -1.000000
# 5  4 -0.857554  0.555556  1.000000  1.000000  0.555556  0.333333  1.000000
# 6  2 -0.857408 -1.000000 -1.000000 -1.000000 -1.000000 -0.777778  1.000000
# 7  2 -0.857339 -0.777778 -1.000000 -0.777778 -1.000000 -0.777778 -1.000000
# 8  2 -0.855171 -0.777778 -1.000000 -1.000000 -1.000000 -0.777778 -1.000000
# 9  2 -0.855171 -0.333333 -0.777778 -1.000000 -1.000000 -0.777778 -1.000000
#
#           i         j         k
# 0 -0.555556 -1.000000 -1.000000
# 1 -0.555556 -0.777778 -1.000000
# 2 -0.555556 -1.000000 -1.000000
# ...

# %%
def init():
    print("reading dataset...")
    # read data in pandas (pd) data frame
    data = df
    
    # put features & outputs in different data frames
    X = pd.DataFrame({"b": df.b,
                                   "c": df.c,
                                   "d": df.d,
                                    "e": df.e,
                                   "f": df.f,
                                   "g": df.g,
                                   "h": df.h, 
                                   "i": df.i, 
                                   "j": df.j, 
                                   "k": df.k})

    Y = pd.DataFrame({"a": df.a})

    # filter features
    remove_correlated_features(X)
    remove_less_significant_features(X, Y)

    # normalize data for better convergence and to prevent overflow
    X_normalized = MinMaxScaler().fit_transform(X.values)
    X = pd.DataFrame(X_normalized)

    # insert 1 in every row for intercept b
    X.insert(loc=len(X.columns), column='intercept', value=1)

    # split data into train and test set
    print("splitting dataset into train and test sets...")
    X_train, X_test, y_train, y_test = tts(X, Y, test_size=0.2, random_state=42)
    
    # train the model
    print("training started...")
    W = sgd(X_train.to_numpy(), y_train.to_numpy())
    print("training finished.")
    print("weights are: {}".format(W))

    # testing the model
    print("testing the model...")
    y_train_predicted = np.array([])
    for i in range(X_train.shape[0]):
        yp = np.sign(np.dot(X_train.to_numpy()[i], W))
        y_train_predicted = np.append(y_train_predicted, yp)

    y_test_predicted = np.array([])
    for i in range(X_test.shape[0]):
        yp = np.sign(np.dot(X_test.to_numpy()[i], W))
        y_test_predicted = np.append(y_test_predicted, yp) 

# set hyper-parameters and call init
regularization_strength = 10000
learning_rate = 0.000001
init()
# Out:
# reading dataset...
# splitting dataset into train and test sets...
# training started...
# Epoch is: 1 and Cost is: 2681.918599590457
# Epoch is: 2 and Cost is: 1237.1617371098932
# Epoch is: 4 and Cost is: 181.36884624860667
# Epoch is: 8 and Cost is: 0.5692800895408624
# Epoch is: 16 and Cost is: 0.5665359619276548
# training finished.
# weights are: [0.4023275 0.4023275 0.4023275 0.4023275 0.4023275 0.4023275 0.4023275]
# testing the model...

# %% [markdown]
# # SVM algorithm by using loop

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=42,stratify=y)
model=[SVC()]

for m in model:
    m.fit(X_train,y_train)
    m.score(X_train,y_train)
    predm=m.predict(X_test)
    print('Accuracy score of',m,'is : ')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('*******************************************************************')
    print('\n')
# Out:
# Accuracy score of SVC() is :
# 0.9736842105263158
# [[44  2]
#  [ 0 30]]
#               precision    recall  f1-score   support
#
#            2       1.00      0.96      0.98        46
#            4       0.94      1.00      0.97        30
#
#     accuracy                           0.97        76
#    macro avg       0.97      0.98      0.97        76
# weighted avg       0.98      0.97      0.97        76
#
# *******************************************************************

# %% [markdown]
# # Cross validate the models

# %%
model=[SVC()]

for m in model:
    score=cross_val_score(m,X,y,cv=10,scoring='accuracy')
    print("model:",m)
    print("Score:",score)
    print("Mean score:",score.mean())
    print("Standard deviation:",score.std())
    print('*******************************************************************')
    print('\n')
# Out:
# model: SVC()
# Score: [0.94736842 1.         1.         0.97368421 0.97368421 0.89473684
#  0.97368421 0.94736842 1.         0.97297297]
# Mean score: 0.9683499288762448
# Standard deviation: 0.0306777624841842
# *******************************************************************

# %%
svm=SVC(probability=True)
svm.fit(X_train,y_train)
svm.score(X_train,y_train)
predsvm=svm.predict(X_test)
print('\n')


print('\n')
print(accuracy_score(y_test,predsvm))

plt.scatter(y_test,predsvm,alpha=0.5)
plt.xlabel("Y_test")
plt.ylabel("Y_pred")
plt.title("Scatter plot between test data and predicted data",fontsize=15)
plt.show()
# Out:
# 0.9736842105263158

# %%
import numpy as np
a=np.array(y_test)
a
# Out:
# array([[2],
#        [2],
#        [4],
#        [2],
#        [2],
#        [2],
#        [4],
#        [4],
#        [2],
#        [4],
#        [2],
#        [2],
#        [2],
#        [2],
#        [4],
#        [2],
#        [4],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [4],
#        [4],
#        [2],
#        [4],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [4],
#        [4],
#        [2],
#        [4],
#        [4],
#        [4],
#        [4],
#        [2],
#        [4],
#        [4],
#        [4],
#        [2],
#        [4],
#        [2],
#        [2],
#        [2],
#        [4],
#        [4],
#        [2],
#        [2],
#        [2],
#        [4],
#        [4],
#        [4],
#        [2],
#        [2],
#        [4],
#        [4],
#        [2],
#        [4],
#        [2],
#        [2],
#        [2],
#        [4],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predsvm,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual compressive strength",fontsize=14)
plt.ylabel("Predicted compressive strength",fontsize=14)
plt.title('Decision Tree Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Saving the model

# %%
import joblib

# %%
joblib.dump(svm,'breast_cancer_sgd.pkl')
# Out:
# ['breast_cancer_sgd.pkl']
